# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ## Data Science Libraries Quiz

# %% [markdown]
# ### Instructions
#
#
# 1. Write code which will produce the specified result
# 2. Enter that result in the green response cell when prompted
# 3. Write code comment(s) to describe the code
#
#
# #### Note:
#
# 1. Complete the work without the help of others
# 2. Enter one code
# comment on Question 0 for 1 point
# 3. There are 9 questions, each worth 11 points
#     - 10 points for code and answers
#     - 1 point for at least one code comment on each question
# 4. You can receive partial credit for your code

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ### Question 0
#
# - Run the following two cells
# - Enter one code comment

# %%
#import libraries and data
from pydataset import data
import pandas as pd
import matplotlib.pyplot as plt

# %%
#assign tips from data to a variable
df = data('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 1       16.99  1.01  Female     No  Sun  Dinner     2
# 2       10.34  1.66    Male     No  Sun  Dinner     3
# 3       21.01  3.50    Male     No  Sun  Dinner     3
# 4       23.68  3.31    Male     No  Sun  Dinner     2
# 5       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-info">
#
# ## Question 1
#
# a) What is the highest total_bill?
#
# b) What time of day did this total_bill occur?

# %%
#used aggregate function to find max value of total_bill column
h = df.total_bill.max()
h
# Out:
# 50.81

# %%
#masked a boolean to get all info of the max bill
df[df.total_bill == h]
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 171       50.81  10.0  Male    Yes  Sat  Dinner     3

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Question 1 Response
#
# a)50.81
#
# b)Dinner on Sat

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-info">
#
# ## Question 2
#
# a) What values are in the smoker column?
#
# b) Are the majority of tables smoking or non-smoking?

# %%
#this shows values in smoker column
df.smoker.values
# Out:
# array(['No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No',
#        'No', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'Yes', 'No',
#        'No', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Yes', 'No',
#        'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Yes', 'Yes', 'No',
#        'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No',
#        'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Yes', 'Yes', 'No',
#        'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Yes', 'No',
#        'No'], dtype=object)

# %%
#used value counts method to return all values along with number of times those values appear
df.smoker.value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Question 2 Response
#
# a)yes/no
#
# b)non-smoking

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-info">
#
# ## Question 3
#
# - What proportion of the bills are from the weekend (Saturday and/or Sunday)?
#     - Assume each table has one bill, regardless of table size
# - Round your answer to two decimal points.

# %%
#filter by sat or sun
s = (df.day == 'Sat') | (df.day == 'Sun')
s.sum()
# Out:
# 163

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Question 3 Response
#
# -

# %% [markdown]
# ---
# <div class="alert alert-block alert-info">
#
# ## Question 4
#
#
# -  Create a column named `percent_tip`.
#
#
# - Calculate the percent_tip based on the formula below.
#
#
#
# > $\texttt{Percent tip} = \dfrac{\texttt{tip amount}}{\texttt{bill}}$
#
# - What was the highest percent tip?

# %%
#using .assign to create new column with calculation
df = df.assign(percent_tip = df.tip / df.total_bill * 100)
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  percent_tip
# 1         16.99  1.01  Female     No   Sun  Dinner     2     5.944673
# 2         10.34  1.66    Male     No   Sun  Dinner     3    16.054159
# 3         21.01  3.50    Male     No   Sun  Dinner     3    16.658734
# 4         23.68  3.31    Male     No   Sun  Dinner     2    13.978041
# 5         24.59  3.61  Female     No   Sun  Dinner     4    14.680765
# ..          ...   ...     ...    ...   ...     ...   ...          ...
# 240       29.03  5.92    Male     No   Sat  Dinner     3    20.392697
# 241       27.18  2.00  Female    Yes   Sat  Dinner     2     7.358352
# 242       22.67  2.00    Male    Yes   Sat  Dinner     2     8.822232
# 243       17.82  1.75    Male     No   Sat  Dinner     2     9.820426
# 244       18.78  3.00  Female     No  Thur  Dinner     2    15.974441
#
# [244 rows x 8 columns]

# %%
df.percent_tip.max()
# Out:
# 71.0344827586207

# %%
#just making sure
df.sort_values(by= 'percent_tip').tail(1)
# Out:
#      total_bill   tip   sex smoker  day    time  size  percent_tip
# 173        7.25  5.15  Male    Yes  Sun  Dinner     2    71.034483

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Question 4 Response
#
# - 71.034483%

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-info">
#
# ## Question 5
#
#
# a) Which time of day has a higher average total_bill, dinner or lunch?
#
# b) What is the difference in the average bill?

# %%
df.groupby('time').total_bill.agg('mean')
# Out:
# time
# Dinner    20.797159
# Lunch     17.168676
# Name: total_bill, dtype: float64

# %%
df.time.value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Question 5 Response
#
# a)
#
# b)

# %% [markdown]
# ---
# <div class="alert alert-block alert-info">
#
# ## Question 6
#
#
# - Rename the column named `size` to `table_size`
# - Verify this column name replaces the former column name
# - Use your new column name to determine:
#     - What is the most common table size?

# %%
#used .rename method
df = df.rename(columns = {'size': 'table_size'})
#verify
df
# Out:
#      total_bill   tip     sex smoker   day    time  table_size  percent_tip
# 1         16.99  1.01  Female     No   Sun  Dinner           2     5.944673
# 2         10.34  1.66    Male     No   Sun  Dinner           3    16.054159
# 3         21.01  3.50    Male     No   Sun  Dinner           3    16.658734
# 4         23.68  3.31    Male     No   Sun  Dinner           2    13.978041
# 5         24.59  3.61  Female     No   Sun  Dinner           4    14.680765
# ..          ...   ...     ...    ...   ...     ...         ...          ...
# 240       29.03  5.92    Male     No   Sat  Dinner           3    20.392697
# 241       27.18  2.00  Female    Yes   Sat  Dinner           2     7.358352
# 242       22.67  2.00    Male    Yes   Sat  Dinner           2     8.822232
# 243       17.82  1.75    Male     No   Sat  Dinner           2     9.820426
# 244       18.78  3.00  Female     No  Thur  Dinner           2    15.974441
#
# [244 rows x 8 columns]

# %%
#shows how many times each size occured
df.table_size.value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: table_size, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Question 6 Response
#
# - 2

# %% [markdown]
# ---
# <div class="alert alert-block alert-info">
#
# ## Question 7
#
# - The following code produces errors.
#
# - Correct the code to determine:
#     - What is the **maximum total_bill** for dinner time on Thursday?

# %% [markdown]
# #### Incorrect code
# ```python
# df.total_bill( (df.day == 'Thursday') and (df.time == 'dinner') )
# ```

# %%
# & instead of and, Thur not Thursday, Dinner not dinner
df[(df.day == 'Thur') & (df.time == 'Dinner')].total_bill
# Out:
# 244    18.78
# Name: total_bill, dtype: float64

# %%
df[df.day == 'Thur']
# Out:
#      total_bill   tip     sex smoker   day    time  table_size  percent_tip
# 78        27.20  4.00    Male     No  Thur   Lunch           4    14.705882
# 79        22.76  3.00    Male     No  Thur   Lunch           2    13.181019
# 80        17.29  2.71    Male     No  Thur   Lunch           2    15.673800
# 81        19.44  3.00    Male    Yes  Thur   Lunch           2    15.432099
# 82        16.66  3.40    Male     No  Thur   Lunch           2    20.408163
# 83        10.07  1.83  Female     No  Thur   Lunch           1    18.172790
# 84        32.68  5.00    Male    Yes  Thur   Lunch           2    15.299878
# 85        15.98  2.03    Male     No  Thur   Lunch           2    12.703379
# 86        34.83  5.17  Female     No  Thur   Lunch           4    14.843526
# 87        13.03  2.00    Male     No  Thur   Lunch           2    15.349194
# 88        18.28  4.00    Male     No  Thur   Lunch           2    21.881838
# 89        24.71  5.85    Male     No  Thur   Lunch           2    23.674626
# 90        21.16  3.00    Male     No  Thur   Lunch           2    14.177694
# 118       10.65  1.50  Female     No  Thur   Lunch           2    14.084507
# 119       12.43  1.80  Female     No  Thur   Lunch           2    14.481094
# 120       24.08  2.92  Female     No  Thur   Lunch           4    12.126246
# 121       11.69  2.31    Male     No  Thur   Lunch           2    19.760479
# 122       13.42  1.68  Female     No  Thur   Lunch           2    12.518629
# 123       14.26  2.50    Male     No  Thur   Lunch           2    17.531557
# 124       15.95  2.00    Male     No  Thur   Lunch           2    12.539185
# 125       12.48  2.52  Female     No  Thur   Lunch           2    20.192308
# 126       29.80  4.20  Female     No  Thur   Lunch           6    14.093960
# 127        8.52  1.48    Male     No  Thur   Lunch           2    17.370892
# 128       14.52  2.00  Female     No  Thur   Lunch           2    13.774105
# 129       11.38  2.00  Female     No  Thur   Lunch           2    17.574692
# 130       22.82  2.18    Male     No  Thur   Lunch           3     9.553024
# 131       19.08  1.50    Male     No  Thur   Lunch           2     7.861635
# 132       20.27  2.83  Female     No  Thur   Lunch           2    13.961519
# 133       11.17  1.50  Female     No  Thur   Lunch           2    13.428827
# 134       12.26  2.00  Female     No  Thur   Lunch           2    16.313214
# 135       18.26  3.25  Female     No  Thur   Lunch           2    17.798467
# 136        8.51  1.25  Female     No  Thur   Lunch           2    14.688602
# 137       10.33  2.00  Female     No  Thur   Lunch           2    19.361084
# 138       14.15  2.00  Female     No  Thur   Lunch           2    14.134276
# 139       16.00  2.00    Male    Yes  Thur   Lunch           2    12.500000
# 140       13.16  2.75  Female     No  Thur   Lunch           2    20.896657
# 141       17.47  3.50  Female     No  Thur   Lunch           2    20.034345
# 142       34.30  6.70    Male     No  Thur   Lunch           6    19.533528
# 143       41.19  5.00    Male     No  Thur   Lunch           5    12.138869
# 144       27.05  5.00  Female     No  Thur   Lunch           6    18.484288
# 145       16.43  2.30  Female     No  Thur   Lunch           2    13.998783
# 146        8.35  1.50  Female     No  Thur   Lunch           2    17.964072
# 147       18.64  1.36  Female     No  Thur   Lunch           3     7.296137
# 148       11.87  1.63  Female     No  Thur   Lunch           2    13.732098
# 149        9.78  1.73    Male     No  Thur   Lunch           2    17.689162
# 150        7.51  2.00    Male     No  Thur   Lunch           2    26.631158
# 192       19.81  4.19  Female    Yes  Thur   Lunch           2    21.150934
# 193       28.44  2.56    Male    Yes  Thur   Lunch           2     9.001406
# 194       15.48  2.02    Male    Yes  Thur   Lunch           2    13.049096
# 195       16.58  4.00    Male    Yes  Thur   Lunch           2    24.125452
# 196        7.56  1.44    Male     No  Thur   Lunch           2    19.047619
# 197       10.34  2.00    Male    Yes  Thur   Lunch           2    19.342360
# 198       43.11  5.00  Female    Yes  Thur   Lunch           4    11.598237
# 199       13.00  2.00  Female    Yes  Thur   Lunch           2    15.384615
# 200       13.51  2.00    Male    Yes  Thur   Lunch           2    14.803849
# 201       18.71  4.00    Male    Yes  Thur   Lunch           3    21.378942
# 202       12.74  2.01  Female    Yes  Thur   Lunch           2    15.777080
# 203       13.00  2.00  Female    Yes  Thur   Lunch           2    15.384615
# 204       16.40  2.50  Female    Yes  Thur   Lunch           2    15.243902
# 205       20.53  4.00    Male    Yes  Thur   Lunch           4    19.483682
# 206       16.47  3.23  Female    Yes  Thur   Lunch           3    19.611415
# 244       18.78  3.00  Female     No  Thur  Dinner           2    15.974441

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Question 7 Response
#
#
# - 18.78

# %% [markdown]
# ---
# <div class="alert alert-block alert-info">
#
# ## Question 8
#
#
# - What is the min, mean, and max total_bill?
# - Use a **histogram** to plot the distribution of the total_bill
#     - add a title

# %%
#.describe method shows all three
df.total_bill.describe()
# Out:
# count    244.000000
# mean      19.785943
# std        8.902412
# min        3.070000
# 25%       13.347500
# 50%       17.795000
# 75%       24.127500
# max       50.810000
# Name: total_bill, dtype: float64

# %%
plt.hist(df.total_bill)
plt.title('Distibution of Total Bill')
# Out:
# Text(0.5, 1.0, 'Distibution of Total Bill')

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Question 8 Response
#
#
# - min = 3.070000
#
#     mean = 19.785943
#
#     max = 50.810000

# %% [markdown]
# ---
# <div class="alert alert-block alert-info">
#
# ## Question 9
#
# - Use matplotlib to create a **scatter plot** for total_bill versus tips
#     - Plot total_bill along the x-axis
#
# - Customize the visualization in at least one way
# - Add axis labels and a title

# %%
#c=colors
plt.scatter(df.total_bill, df.tip, c='red')
plt.title('Total Bill vs Tip')
plt.xlabel('total_bill')
plt.ylabel('tip')
# Out:
# Text(0, 0.5, 'tip')
