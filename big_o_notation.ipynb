# %%
import numpy as np
import pandas as pd
import math
from pydataset import data

import matplotlib.pyplot as plt

# %%
plt.title('Big O Notation')
plt.xlabel('Elements')
plt.ylabel('Operations')
plt.legend()
text.usetex : true
font.family : Helvetica
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       3 plt.ylabel('Operations')
#       4 plt.legend()
# ----> 5 text.usetex : true
#       6 font.family : Helvetica
#
# NameError: name 'text' is not defined

# %%
x = np.linspace(0, 10, 100)
n = np.arange(100)
y1 = 0 * n + 1
y2 = np.log(n)
y3 = n
y4 = n * np.log(n)
y5 = n ** 2
y6 = 2 ** n
y7 = np.array([math.factorial(i) for i in n])
y8 = n ** n

plt.plot(x, y1, label='O(1)', color='blue')
plt.plot(x, y2, label='O(log n)', color='red')
plt.plot(x, y3, label='O(n)', color='purple')
plt.plot(x, y4, label='O(n log n)', color='green')
plt.plot(x, y5, label='O(n^2)', color='yellow')
plt.plot(x, y6, label='O(2^n)', color='black')
plt.plot(x, y7, label='O(n!)', color='orange')
plt.plot(x, y8, label='O(n^n)', color='silver')

plt.title('Big O Notation')
plt.xlabel('Elements')
plt.ylabel('Operations')
plt.legend()
text.usetex : true
font.family : Helvetica
# Out:
# /var/folders/xv/ltdj6hd169j2bd0gclmjj3th0000gn/T/ipykernel_11473/1255339177.py:4: RuntimeWarning: divide by zero encountered in log
#   y2 = np.log(n)
# /var/folders/xv/ltdj6hd169j2bd0gclmjj3th0000gn/T/ipykernel_11473/1255339177.py:6: RuntimeWarning: divide by zero encountered in log
#   y4 = n * np.log(n)
# /var/folders/xv/ltdj6hd169j2bd0gclmjj3th0000gn/T/ipykernel_11473/1255339177.py:6: RuntimeWarning: invalid value encountered in multiply
#   y4 = n * np.log(n)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 25
#      23 plt.ylabel('Operations')
#      24 plt.legend()
# ---> 25 text.usetex : true
#      26 font.family : Helvetica
#
# NameError: name 'text' is not defined
